# %%
import pandas as pd

# %%
df = pd.read_csv('yemen.csv', encoding='cp1252')

# %%
df
# Out:
#        Incident ID        Date Governorate            District  \
# 0                1  26/03/2015     Capital      Bani Al-Harith
# 1                2  26/03/2015     Capital      Bani Al-Harith
# 2                3  26/03/2015     Capital      Bani Al-Harith
# 3                4  26/03/2015     Capital          Al-Sab'ein
# 4                5  26/03/2015     Capital          Al-Thawrah
# ...            ...         ...         ...                 ...
# 22480        22482  31/12/2020       Sanaa              Sanhan
# 22481        22483  31/12/2020       Sanaa              Sanhan
# 22482        22484  31/12/2020       Sanaa       Bani Hushaysh
# 22483        22485  31/12/2020     Capital      Bani Al-Harith
# 22484        22486  31/12/2020       Marib  Medghal Al-Jeda'an
#
#                               Area                        Target  \
# 0                       Al-Rahabah            Al-Daylami Airbase
# 1                          Airport  Sana'a International Airport
# 2         Al-Sonblah Neighbourhood              Residential Area
# 3                       Al-Nahdain           Presidential Palace
# 4                       Al-Nahdhah  Former 1st Armoured Division
# ...                            ...                           ...
# 22480  Raymat Humayd Military Camp   Raymat Humayd Military Camp
# 22481  Raymat Humayd Military Camp   Raymat Humayd Military Camp
# 22482                   Wadi Rijam                       Unknown
# 22483                   Ar Rahabah           Al-Daylami Air base
# 22484                          NaN                       Unknown
#
#                   Main category      Sub-category  Min Air Raids  \
# 0      Military_Security_Target     Military Site              1
# 1                Infrastructure         Transport              1
# 2                      Civilian  Residential Area              1
# 3      Military_Security_Target     Military Site              1
# 4      Military_Security_Target     Military Site              1
# ...                         ...               ...            ...
# 22480  Military_Security_Target     Military site              1
# 22481  Military_Security_Target     Military site              1
# 22482                   Unknown           Unknown              1
# 22483  Military_Security_Target     Military site              1
# 22484                   Unknown           Unknown              1
#
#       Max Air Raids  ...  Child fatalities  Injured   Woman injured  \
# 0                 2  ...                 0         0              0
# 1                 2  ...                 0         0              0
# 2                 2  ...                14         8              0
# 3                 2  ...                 0         0              0
# 4                 2  ...                 0         0              0
# ...             ...  ...               ...       ...            ...
# 22480             5  ...                 0         0              0
# 22481             2  ...                 0         0              0
# 22482             2  ...                 0         0              0
# 22483             1  ...                 0         0              0
# 22484             4  ...                 0         0              0
#
#        Child injured   Confirmed Time    Time of Day  Unnamed: 19 Unnamed: 20  \
# 0                0.0                2  Early-Morning          NaN         NaN
# 1                0.0                2  Early-Morning          NaN         NaN
# 2                7.0                2  Early-Morning          NaN         NaN
# 3                0.0                3  Early-Morning          NaN         NaN
# 4                0.0                3  Early-Morning          NaN         NaN
# ...              ...              ...            ...          ...         ...
# 22480            0.0                1  Early-Morning          0.0           0
# 22481            0.0                2  Early-Morning          0.0           0
# 22482            0.0                3  Early-Morning          0.0           0
# 22483            0.0                1  Early-Morning          0.0           0
# 22484            0.0               18        Evening          0.0           0
#
#       Unnamed: 21                  Unnamed: 22
# 0             NaN                          NaN
# 1             NaN                          NaN
# 2             NaN                          NaN
# 3             NaN                          NaN
# 4             NaN                          NaN
# ...           ...                          ...
# 22480           0  Raymat Humayd Military Camp
# 22481           0  Raymat Humayd Military Camp
# 22482           0                   Wadi Rijam
# 22483           0                   Ar Rahabah
# 22484           0                          NaN
#
# [22485 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# Incident ID                0
# Date                       0
# Governorate                0
# District                 238
# Area                    3299
# Target                     0
# Main category              0
# Sub-category               0
# Min Air Raids              0
# Max Air Raids              2
# Civilian Casualties        0
# Fatalities                 0
# Woman fatalities           0
# Child fatalities           0
# Injured                    0
# Woman injured              0
# Child injured              2
#  Confirmed Time          146
# Time of Day                0
# Unnamed: 19            22360
# Unnamed: 20            22360
# Unnamed: 21            22360
# Unnamed: 22            22436
# dtype: int64

# %%
len(df['Area'].unique())
# Out:
# 5805

# %%
df.columns
# Out:
# Index(['Incident ID', 'Date', 'Governorate', 'District', 'Area', 'Target',
#        'Main category', 'Sub-category', 'Min Air Raids', 'Max Air Raids',
#        'Civilian Casualties', 'Fatalities ', 'Woman fatalities',
#        'Child fatalities', 'Injured ', 'Woman injured', 'Child injured',
#        ' Confirmed Time', 'Time of Day', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
#df = df.drop(columns=['Unnamed: 19', 'Unnamed: 20',
#       'Unnamed: 21', 'Unnamed: 22'])

# %%
df
# Out:
#        Incident ID        Date Governorate            District  \
# 0                1  26/03/2015     Capital      Bani Al-Harith
# 1                2  26/03/2015     Capital      Bani Al-Harith
# 2                3  26/03/2015     Capital      Bani Al-Harith
# 3                4  26/03/2015     Capital          Al-Sab'ein
# 4                5  26/03/2015     Capital          Al-Thawrah
# ...            ...         ...         ...                 ...
# 22480        22482  31/12/2020       Sanaa              Sanhan
# 22481        22483  31/12/2020       Sanaa              Sanhan
# 22482        22484  31/12/2020       Sanaa       Bani Hushaysh
# 22483        22485  31/12/2020     Capital      Bani Al-Harith
# 22484        22486  31/12/2020       Marib  Medghal Al-Jeda'an
#
#                               Area                        Target  \
# 0                       Al-Rahabah            Al-Daylami Airbase
# 1                          Airport  Sana'a International Airport
# 2         Al-Sonblah Neighbourhood              Residential Area
# 3                       Al-Nahdain           Presidential Palace
# 4                       Al-Nahdhah  Former 1st Armoured Division
# ...                            ...                           ...
# 22480  Raymat Humayd Military Camp   Raymat Humayd Military Camp
# 22481  Raymat Humayd Military Camp   Raymat Humayd Military Camp
# 22482                   Wadi Rijam                       Unknown
# 22483                   Ar Rahabah           Al-Daylami Air base
# 22484                          NaN                       Unknown
#
#                   Main category      Sub-category  Min Air Raids  \
# 0      Military_Security_Target     Military Site              1
# 1                Infrastructure         Transport              1
# 2                      Civilian  Residential Area              1
# 3      Military_Security_Target     Military Site              1
# 4      Military_Security_Target     Military Site              1
# ...                         ...               ...            ...
# 22480  Military_Security_Target     Military site              1
# 22481  Military_Security_Target     Military site              1
# 22482                   Unknown           Unknown              1
# 22483  Military_Security_Target     Military site              1
# 22484                   Unknown           Unknown              1
#
#       Max Air Raids  ...  Child fatalities  Injured   Woman injured  \
# 0                 2  ...                 0         0              0
# 1                 2  ...                 0         0              0
# 2                 2  ...                14         8              0
# 3                 2  ...                 0         0              0
# 4                 2  ...                 0         0              0
# ...             ...  ...               ...       ...            ...
# 22480             5  ...                 0         0              0
# 22481             2  ...                 0         0              0
# 22482             2  ...                 0         0              0
# 22483             1  ...                 0         0              0
# 22484             4  ...                 0         0              0
#
#        Child injured   Confirmed Time    Time of Day  Unnamed: 19 Unnamed: 20  \
# 0                0.0                2  Early-Morning          NaN         NaN
# 1                0.0                2  Early-Morning          NaN         NaN
# 2                7.0                2  Early-Morning          NaN         NaN
# 3                0.0                3  Early-Morning          NaN         NaN
# 4                0.0                3  Early-Morning          NaN         NaN
# ...              ...              ...            ...          ...         ...
# 22480            0.0                1  Early-Morning          0.0           0
# 22481            0.0                2  Early-Morning          0.0           0
# 22482            0.0                3  Early-Morning          0.0           0
# 22483            0.0                1  Early-Morning          0.0           0
# 22484            0.0               18        Evening          0.0           0
#
#       Unnamed: 21                  Unnamed: 22
# 0             NaN                          NaN
# 1             NaN                          NaN
# 2             NaN                          NaN
# 3             NaN                          NaN
# 4             NaN                          NaN
# ...           ...                          ...
# 22480           0  Raymat Humayd Military Camp
# 22481           0  Raymat Humayd Military Camp
# 22482           0                   Wadi Rijam
# 22483           0                   Ar Rahabah
# 22484           0                          NaN
#
# [22485 rows x 23 columns]

# %%
df['Child injured'] = df['Child injured'].fillna(df['Child injured'].mean())
df['Max Air Raids'] = df['Max Air Raids'].fillna(df['Max Air Raids'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-c97cbf0bfd06> in <module>
#       1 df['Child injured'] = df['Child injured'].fillna(df['Child injured'].mean())
# ----> 2 df['Max Air Raids'] = df['Max Air Raids'].fillna(df['Max Air Raids'].mean())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     561         dtype_count = dtype
#     562     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 563     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     564
#     565     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Out:
# 2       9435
# 1       5802
# 3       2237
# 4       1381
# 5        881
#         ...
# 17+        1
# 250+       1
# 38         1
# 29         1
# 75         1
# Name: Max Air Raids, Length: 86, dtype: int64

# %%
max_air_raids = []
for value in df['Max Air Raids']:
    if value != '-':
        val = int(value.strip('+'))
    elif value == 
    else:
        val = 0
    max_air_raids.append(val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-53d19724dd1b> in <module>
#       2 for value in df['Max Air Raids']:
#       3     if value != '-':
# ----> 4         val = int(value.strip('+'))
#       5     else:
#       6         val == 0
#
# ValueError: invalid literal for int() with base 10: '2,2'

# %%
df.set_index('Incident ID')
# Out:
#                    Date Governorate            District  \
# Incident ID
# 1            26/03/2015     Capital      Bani Al-Harith
# 2            26/03/2015     Capital      Bani Al-Harith
# 3            26/03/2015     Capital      Bani Al-Harith
# 4            26/03/2015     Capital          Al-Sab'ein
# 5            26/03/2015     Capital          Al-Thawrah
# ...                 ...         ...                 ...
# 22482        31/12/2020       Sanaa              Sanhan
# 22483        31/12/2020       Sanaa              Sanhan
# 22484        31/12/2020       Sanaa       Bani Hushaysh
# 22485        31/12/2020     Capital      Bani Al-Harith
# 22486        31/12/2020       Marib  Medghal Al-Jeda'an
#
#                                     Area                        Target  \
# Incident ID
# 1                             Al-Rahabah            Al-Daylami Airbase
# 2                                Airport  Sana'a International Airport
# 3               Al-Sonblah Neighbourhood              Residential Area
# 4                             Al-Nahdain           Presidential Palace
# 5                             Al-Nahdhah  Former 1st Armoured Division
# ...                                  ...                           ...
# 22482        Raymat Humayd Military Camp   Raymat Humayd Military Camp
# 22483        Raymat Humayd Military Camp   Raymat Humayd Military Camp
# 22484                         Wadi Rijam                       Unknown
# 22485                         Ar Rahabah           Al-Daylami Air base
# 22486                                NaN                       Unknown
#
#                         Main category      Sub-category  Min Air Raids  \
# Incident ID
# 1            Military_Security_Target     Military Site              1
# 2                      Infrastructure         Transport              1
# 3                            Civilian  Residential Area              1
# 4            Military_Security_Target     Military Site              1
# 5            Military_Security_Target     Military Site              1
# ...                               ...               ...            ...
# 22482        Military_Security_Target     Military site              1
# 22483        Military_Security_Target     Military site              1
# 22484                         Unknown           Unknown              1
# 22485        Military_Security_Target     Military site              1
# 22486                         Unknown           Unknown              1
#
#             Max Air Raids  Civilian Casualties  ...  Child fatalities  \
# Incident ID                                     ...
# 1                       2                    0  ...                 0
# 2                       2                    0  ...                 0
# 3                       2                   29  ...                14
# 4                       2                    0  ...                 0
# 5                       2                    0  ...                 0
# ...                   ...                  ...  ...               ...
# 22482                   5                    0  ...                 0
# 22483                   2                    0  ...                 0
# 22484                   2                    0  ...                 0
# 22485                   1                    0  ...                 0
# 22486                   4                    0  ...                 0
#
#              Injured   Woman injured  Child injured   Confirmed Time  \
# Incident ID
# 1                   0              0            0.0                2
# 2                   0              0            0.0                2
# 3                   8              0            7.0                2
# 4                   0              0            0.0                3
# 5                   0              0            0.0                3
# ...               ...            ...            ...              ...
# 22482               0              0            0.0                1
# 22483               0              0            0.0                2
# 22484               0              0            0.0                3
# 22485               0              0            0.0                1
# 22486               0              0            0.0               18
#
#                Time of Day Unnamed: 19 Unnamed: 20  Unnamed: 21  \
# Incident ID
# 1            Early-Morning         NaN         NaN          NaN
# 2            Early-Morning         NaN         NaN          NaN
# 3            Early-Morning         NaN         NaN          NaN
# 4            Early-Morning         NaN         NaN          NaN
# 5            Early-Morning         NaN         NaN          NaN
# ...                    ...         ...         ...          ...
# 22482        Early-Morning         0.0           0            0
# 22483        Early-Morning         0.0           0            0
# 22484        Early-Morning         0.0           0            0
# 22485        Early-Morning         0.0           0            0
# 22486              Evening         0.0           0            0
#
#                              Unnamed: 22
# Incident ID
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# ...                                  ...
# 22482        Raymat Humayd Military Camp
# 22483        Raymat Humayd Military Camp
# 22484                         Wadi Rijam
# 22485                         Ar Rahabah
# 22486                                NaN
#
# [22485 rows x 22 columns]
